# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import csv 
import seaborn as sns
import os 
# %matplotlib inline
os.chdir("/Users/susanchen/Desktop/TechSalary")
plt.style.use('bmh')

# %%
datapath = ("/Users/susanchen/Desktop/TechSalary/entryLevel.csv")
df = pd.read_csv(datapath)
datapath2 = ("/Users/susanchen/Desktop/TechSalary/levelsFYIallSalary.csv")
df2 = pd.read_csv(datapath2)

# %%
df.drop("Unnamed: 0", axis =1, inplace=True)
df2.drop("Unnamed: 0", axis =1, inplace=True)

# %%
#recoding Company
conditions = [
    (df['company'] == "Facebook"),
    (df['company'] == "Amazon"),
    (df['company'] == "Apple"),
    (df['company'] == "Google"),
    (df['company'] == "Twitter"),
    (df['company'] == "Microsoft")
    ]

values = ['Facebook','Amazon','Apple','Google','Twitter', 'Microsoft']
df['Company'] = np.select(conditions, values)


def company(series):
    if series == '0':
        return 'Others'
    else:
        return series

df['Company'] = df['Company'].apply(company)

df
# Out:
#                 timestamp    company              level  \
# 0     2017-06-07 11:33:27     Oracle                 L3
# 1     2017-06-29 15:14:16  Microsoft                 59
# 2     2017-07-20 22:35:49   Facebook                 E3
# 3     2017-07-25 11:01:33     Amazon             SDE II
# 4     2017-08-20 19:16:32      Apple               ICT2
# ...                   ...        ...                ...
# 5844  2020-08-26 09:32:11  Microsoft                 L3
# 5845  2020-08-26 10:04:49     Amazon                 L4
# 5846  2020-08-26 10:16:24  Postmates                 P5
# 5847  2020-08-26 11:32:15   Qualcomm  Software Engineer
# 5848  2020-08-26 11:40:22        hpe       Intermediate
#
#                              title  totalyearlycompensation  \
# 0                  Product Manager                    127.0
# 1                Software Engineer                    137.0
# 2                Software Engineer                    168.0
# 3                Software Engineer                    212.0
# 4                Software Engineer                    160.0
# ...                            ...                      ...
# 5844  Software Engineering Manager                    120.0
# 5845             Software Engineer                    157.0
# 5846             Software Engineer                    169.0
# 5847             Software Engineer                    116.0
# 5848             Software Engineer                    130.0
#
#                location  yearsofexperience  yearsatcompany  \
# 0      Redwood City, CA                1.5             1.5
# 1           Seattle, WA                1.0             1.0
# 2        Menlo Park, CA                1.0             1.0
# 3           Seattle, WA                2.0             0.0
# 4         Cupertino, CA                0.0             0.0
# ...                 ...                ...             ...
# 5844  San Francisco, CA                1.0             1.0
# 5845          Tempe, AZ                0.0             0.0
# 5846  San Francisco, CA                2.0             2.0
# 5847      San Diego, CA                2.0             2.0
# 5848    Santa Clara, CA                2.0             2.0
#
#                                  tag  basesalary  stockgrantvalue    bonus  \
# 0                                NaN       107.0             20.0     10.0
# 1                                NaN    110000.0          16000.0  11000.0
# 2                                NaN         NaN              NaN      NaN
# 3                                NaN    150000.0           7500.0  55000.0
# 4                                NaN    105000.0              NaN      NaN
# ...                              ...         ...              ...      ...
# 5844                         Android        10.0             10.0    100.0
# 5845      API Development (Back-End)       116.0             22.0     15.0
# 5846  Distributed Systems (Back-End)       145.0             24.0      0.0
# 5847          Mobile (iOS + Android)       101.0              9.0      6.0
# 5848                      Networking       127.0              1.0      2.0
#
#      gender                                       otherdetails    Company
# 0       NaN                                                NaN     Others
# 1       NaN                                                NaN  Microsoft
# 2       NaN                                                NaN   Facebook
# 3       NaN                                                NaN     Amazon
# 4       NaN                                                NaN      Apple
# ...     ...                                                ...        ...
# 5844   Male  Race: Hispanic / Latino, Academic Level: High ...  Microsoft
# 5845   Male  $7k relocation, Race: Asian, Academic Level: B...     Amazon
# 5846   Male     Race: White, Academic Level: Bachelor’s degree     Others
# 5847   Male     Race: White, Academic Level: Bachelor’s degree     Others
# 5848    NaN                                                NaN     Others
#
# [5849 rows x 15 columns]

# %%
df2
# Out:
#                 timestamp       company level                         title  \
# 0       6/7/2017 11:33:27        Oracle    L3               Product Manager
# 1      6/10/2017 17:11:29          eBay  SE 2             Software Engineer
# 2      6/11/2017 14:53:57        Amazon    L7               Product Manager
# 3      6/14/2017 21:22:25     Microsoft    64  Software Engineering Manager
# 4      6/16/2017 10:44:01        Amazon    L5             Software Engineer
# ...                   ...           ...   ...                           ...
# 27075  8/26/2020 11:57:35    Salesforce  smts             Software Engineer
# 27076  8/26/2020 12:16:17       Shopify    L6             Software Engineer
# 27077  8/26/2020 12:27:00     Microsoft    61             Software Engineer
# 27078  8/26/2020 12:27:41        Amazon    L5             Software Engineer
# 27079  8/26/2020 12:27:44  Walmart Labs    L4             Software Engineer
#
#        totalyearlycompensation               location  yearsofexperience  \
# 0                        127.0       Redwood City, CA                1.5
# 1                        100.0      San Francisco, CA                5.0
# 2                        310.0            Seattle, WA                8.0
# 3                        200.0            Redmond, WA                9.0
# 4                        173.0  Vancouver, BC, Canada               11.0
# ...                        ...                    ...                ...
# 27075                    240.0      San Francisco, CA                4.0
# 27076                    197.0       Philadelphia, PA                8.0
# 27077                    186.0            Redmond, WA                7.0
# 27078                    297.0            Seattle, WA                5.0
# 27079                     61.0   Bangalore, KA, India                5.0
#
#        yearsatcompany                             tag  basesalary  \
# 0                 1.5                             NaN       107.0
# 1                 3.0                             NaN         NaN
# 2                 0.0                             NaN       155.0
# 3                 9.0                             NaN    169000.0
# 4                 1.0                             NaN    120000.0
# ...               ...                             ...         ...
# 27075             2.0                            Data       180.0
# 27076             0.0      API Development (Back-End)       155.0
# 27077             1.0  Distributed Systems (Back-End)       138.0
# 27078             3.0                           Cloud       153.0
# 27079             2.0      API Development (Back-End)        43.0
#
#        stockgrantvalue    bonus gender  \
# 0                 20.0     10.0    NaN
# 1                  NaN      NaN    NaN
# 2                  NaN      NaN    NaN
# 3             100000.0  30000.0    NaN
# 4                  NaN  53000.0    NaN
# ...                ...      ...    ...
# 27075             30.0     30.0    NaN
# 27076             42.0      0.0    NaN
# 27077              0.0     48.0   Male
# 27078            144.0      0.0   Male
# 27079              7.0     11.0   Male
#
#                                          otherdetails
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 27075                                             NaN
# 27076                                          Remote
# 27077    Race: White, Academic Level: Doctorate (PhD)
# 27078  Race: White, Academic Level: Bachelor’s degree
# 27079  Race: Asian, Academic Level: Bachelor’s degree
#
# [27080 rows x 14 columns]

# %%
#recoding Company
conditions2 = [
    (df2['company'] == "Facebook"),
    (df2['company'] == "Amazon"),
    (df2['company'] == "Apple"),
    (df2['company'] == "Google"),
    (df2['company'] == "Twitter"),
    (df2['company'] == "Microsoft")
    ]

values = ['Facebook','Amazon','Apple','Google','Twitter', 'Microsoft']
df2['Company'] = np.select(conditions2, values)


def company(series):
    if series == '0':
        return 'Others'
    else:
        return series

df2['Company'] = df2['Company'].apply(company)

df2
# Out:
#                 timestamp       company level                         title  \
# 0       6/7/2017 11:33:27        Oracle    L3               Product Manager
# 1      6/10/2017 17:11:29          eBay  SE 2             Software Engineer
# 2      6/11/2017 14:53:57        Amazon    L7               Product Manager
# 3      6/14/2017 21:22:25     Microsoft    64  Software Engineering Manager
# 4      6/16/2017 10:44:01        Amazon    L5             Software Engineer
# ...                   ...           ...   ...                           ...
# 27075  8/26/2020 11:57:35    Salesforce  smts             Software Engineer
# 27076  8/26/2020 12:16:17       Shopify    L6             Software Engineer
# 27077  8/26/2020 12:27:00     Microsoft    61             Software Engineer
# 27078  8/26/2020 12:27:41        Amazon    L5             Software Engineer
# 27079  8/26/2020 12:27:44  Walmart Labs    L4             Software Engineer
#
#        totalyearlycompensation               location  yearsofexperience  \
# 0                        127.0       Redwood City, CA                1.5
# 1                        100.0      San Francisco, CA                5.0
# 2                        310.0            Seattle, WA                8.0
# 3                        200.0            Redmond, WA                9.0
# 4                        173.0  Vancouver, BC, Canada               11.0
# ...                        ...                    ...                ...
# 27075                    240.0      San Francisco, CA                4.0
# 27076                    197.0       Philadelphia, PA                8.0
# 27077                    186.0            Redmond, WA                7.0
# 27078                    297.0            Seattle, WA                5.0
# 27079                     61.0   Bangalore, KA, India                5.0
#
#        yearsatcompany                             tag  basesalary  \
# 0                 1.5                             NaN       107.0
# 1                 3.0                             NaN         NaN
# 2                 0.0                             NaN       155.0
# 3                 9.0                             NaN    169000.0
# 4                 1.0                             NaN    120000.0
# ...               ...                             ...         ...
# 27075             2.0                            Data       180.0
# 27076             0.0      API Development (Back-End)       155.0
# 27077             1.0  Distributed Systems (Back-End)       138.0
# 27078             3.0                           Cloud       153.0
# 27079             2.0      API Development (Back-End)        43.0
#
#        stockgrantvalue    bonus gender  \
# 0                 20.0     10.0    NaN
# 1                  NaN      NaN    NaN
# 2                  NaN      NaN    NaN
# 3             100000.0  30000.0    NaN
# 4                  NaN  53000.0    NaN
# ...                ...      ...    ...
# 27075             30.0     30.0    NaN
# 27076             42.0      0.0    NaN
# 27077              0.0     48.0   Male
# 27078            144.0      0.0   Male
# 27079              7.0     11.0   Male
#
#                                          otherdetails    Company
# 0                                                 NaN     Others
# 1                                                 NaN     Others
# 2                                                 NaN     Amazon
# 3                                                 NaN  Microsoft
# 4                                                 NaN     Amazon
# ...                                               ...        ...
# 27075                                             NaN     Others
# 27076                                          Remote     Others
# 27077    Race: White, Academic Level: Doctorate (PhD)  Microsoft
# 27078  Race: White, Academic Level: Bachelor’s degree     Amazon
# 27079  Race: Asian, Academic Level: Bachelor’s degree     Others
#
# [27080 rows x 15 columns]

# %%
df.groupby(["title", "Company"]).size()
# Out:
# title                         Company
# Data Scientist                Amazon         32
#                               Apple           9
#                               Facebook       25
#                               Google         15
#                               Microsoft      55
#                               Others        174
#                               Twitter         6
# Hardware Engineer             Amazon          5
#                               Apple          32
#                               Facebook        6
#                               Google          5
#                               Microsoft      17
#                               Others         84
# Management Consultant         Amazon          1
#                               Others         32
# Product Designer              Amazon          7
#                               Apple           2
#                               Facebook        7
#                               Google          7
#                               Microsoft      10
#                               Others         52
# Product Manager               Amazon         14
#                               Apple           3
#                               Facebook        7
#                               Google          8
#                               Microsoft      88
#                               Others         95
#                               Twitter         2
# Software Engineer             Amazon        840
#                               Apple         191
#                               Facebook      333
#                               Google        592
#                               Microsoft     590
#                               Others       2416
#                               Twitter        35
# Software Engineering Manager  Amazon          1
#                               Facebook        1
#                               Microsoft       2
#                               Others          9
# Solution Architect            Amazon         10
#                               Google          2
#                               Microsoft       2
#                               Others          4
# Technical Program Manager     Apple           4
#                               Facebook        4
#                               Google          1
#                               Microsoft       8
#                               Others          4
# dtype: int64

# %%
df["title"].value_counts()
# Out:
# Software Engineer               4997
# Data Scientist                   316
# Product Manager                  217
# Hardware Engineer                149
# Product Designer                  85
# Management Consultant             33
# Technical Program Manager         21
# Solution Architect                18
# Software Engineering Manager      13
# Name: title, dtype: int64

# %%
df["Company"].value_counts()
# Out:
# Others       2870
# Amazon        910
# Microsoft     772
# Google        630
# Facebook      383
# Apple         241
# Twitter        43
# Name: Company, dtype: int64

# %%
plot1 = df.groupby('Company').totalyearlycompensation.mean().sort_values().plot.barh(grid= True, title = "Facebook and Twitter pays the most for entry level tech jobs on average ")
plot1.set_xlabel('Total Yearly Compensation (in thousands)', fontsize =15)
plot1.set_ylabel('Company', fontsize =15)


#Facebook and Twitter pays the most for entry level tech jobs on average
# Out:
# Text(0, 0.5, 'Company')

# %%
plot2 =df.groupby('title').totalyearlycompensation.mean().sort_values().plot.bar(grid= True, title = "Data Scientists Earn the Most \n on Average", rot = -45, fontsize = 12)
#plot2.set(xlabel= 'Job Title', ylabel = 'Mean Yearly Compensation (in thousands)')
plot2.set_xlabel('Job Title', fontsize = 15)
plot2.set_ylabel('Mean Yearly Compensation (in thousands)', fontsize= 15)


for tick in plot2.xaxis.get_majorticklabels():
    tick.set_horizontalalignment("left")
#data scientist earn the most on average

# %%
plot4 = df.boxplot(patch_artist = True,
                   column = 'totalyearlycompensation',
                   fontsize = 15,
                   by ='Company', 
                   vert = False, 
                   showfliers= False, 
                   showmeans = True, 
                   meanline = True, 
                   whis = "range", 
                   medianprops={'linestyle': '--', 'linewidth': 2.5, 'color': 'orange'}, 
                   meanprops ={"linewidth": 2.5},
                   whiskerprops ={'linestyle': '--', 'linewidth': 2, "color": 'black'},
                   capprops ={'linewidth':2 })
                   #boxprops = {'color':'black'})
#plt.legend()
plt.suptitle('')
plt.figure(figsize=(15,10))
plot4.set_title('Entry Level Salary Median, Range, and IQR by Comany', fontsize =22)
plot4.set_xlabel('Total Yearly Compensation (in thousands)', fontsize=20)
# Out:
# Text(0.5, 0, 'Total Yearly Compensation (in thousands)')

# %%
#plt.rcParams["figure.figsize"] = (15,10)
plot3 = df.boxplot(patch_artist = True,
                   column = 'totalyearlycompensation',
                   fontsize = 15,
                   by ='title', 
                   vert = False, 
                   showfliers= False, 
                   showmeans = True, 
                   meanline = True, 
                   whis = "range", 
                   medianprops={'linestyle': '--', 'linewidth': 2.5, 'color': 'orange'}, 
                   meanprops ={"linewidth": 2.5},
                   whiskerprops ={'linestyle': '--', 'linewidth': 2, "color": 'black'},
                   capprops ={'linewidth':2 })
                   #boxprops = {'color':'black'})
#plt.legend()
plt.suptitle('')
plt.figure(figsize=(15,10))
plot3.set_title('Entry Level Salary Median, Range, and IQR by title', fontsize =22)
plot3.set_xlabel('Total Yearly Compensation (in thousands)', fontsize=20)
# Out:
# Text(0.5, 0, 'Total Yearly Compensation (in thousands)')
